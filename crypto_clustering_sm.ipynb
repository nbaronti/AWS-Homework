# %% [markdown]
# # Clustering Crypto

# %%
# !pip install -U altair
# Out:
# Requirement already satisfied: altair in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (4.2.0)
# Requirement already satisfied: numpy in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from altair) (1.20.3)
# Requirement already satisfied: entrypoints in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from altair) (0.3)
# Requirement already satisfied: toolz in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from altair) (0.11.2)
# Requirement already satisfied: pandas>=0.18 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from altair) (1.3.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from altair) (3.2.0)
# Requirement already satisfied: jinja2 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from altair) (2.11.3)
# Requirement already satisfied: six>=1.11.0 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from jsonschema>=3.0->altair) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: setuptools in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from jsonschema>=3.0->altair) (58.0.4)
# Requirement already satisfied: importlib-metadata in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from jsonschema>=3.0->altair) (4.8.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from jsonschema>=3.0->altair) (21.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from pandas>=0.18->altair) (2021.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from importlib-metadata->jsonschema>=3.0->altair) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from importlib-metadata->jsonschema>=3.0->altair) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/nbaronti/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages (from jinja2->altair) (1.1.1)

# %%
# Initial imports
import requests
import pandas as pd
import altair as alt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path

import requests
import json

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# Submit request and format output
response_data = requests.get(url).json()
print(json.dumps(response_data, indent=4))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Create DataFrame
crypto_df = pd.DataFrame(response_data['Data'])
crypto_df = crypto_df.transpose(copy=True)
crypto_df.loc["BTC"]
# Out:
# Id                                                                   1182
# Url                                                   /coins/btc/overview
# ImageUrl                                          /media/37746251/btc.png
# ContentCreatedOn                                               1417635237
# Name                                                                  BTC
# Symbol                                                                BTC
# CoinName                                                          Bitcoin
# FullName                                                    Bitcoin (BTC)
# Description             Bitcoin uses peer-to-peer technology to operat...
# AssetTokenStatus                                                      N/A
# Algorithm                                                         SHA-256
# ProofType                                                             PoW
# SortOrder                                                               1
# Sponsored                                                           False
# Taxonomy                {'Access': 'Permissionless', 'FCA': 'Exchange'...
# Rating                  {'Weiss': {'Rating': 'B+', 'TechnologyAdoption...
# IsTrading                                                            True
# TotalCoinsMined                                                  18956275
# CirculatingSupply                                                18956275
# BlockNumber                                                        723003
# NetHashesPerSecond                                  238822777546812030000
# BlockReward                                                          6.25
# BlockTime                                                             474
# AssetLaunchDate                                                2009-01-03
# AssetWhitepaperUrl      https://www.cryptocompare.com/media/37745820/b...
# AssetWebsiteUrl                                   https://bitcoin.org/en/
# MaxSupply                                                   20999999.9769
# MktCapPenalty                                                           0
# IsUsedInDefi                                                            0
# IsUsedInNft                                                             0
# PlatformType                                                   blockchain
# AlgorithmType                                                     sha-256
# Difficulty                                                 26690525287406
# BuiltOn                                                               NaN
# SmartContractAddress                                                  NaN
# DecimalPoints                                                           8
# Name: BTC, dtype: object

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','CirculatingSupply']].copy()
crypto_df
# Out:
#               CoinName  Algorithm IsTrading ProofType   TotalCoinsMined  \
# 42             42 Coin     Scrypt      True   PoW/PoS         41.999952
# 300          300 token        N/A      True       N/A               300
# 365            365Coin        X11      True   PoW/PoS                 0
# 404            404Coin     Scrypt      True   PoW/PoS                 0
# 433          433 Token        N/A     False       N/A               NaN
# ...                ...        ...       ...       ...               ...
# OLT          OneLedger        N/A      True       N/A        1000000000
# RNT    OneRoot Network        N/A      True       N/A         400000000
# OPEN     Open Platform        N/A      True       N/A        1745447045
# SIGNA            Signa  Shabal256      True       PoC        2139048800
# UPR             Upfire        N/A      True       N/A  772299898.370118
#
#       CirculatingSupply
# 42            41.999952
# 300                   0
# 365                   0
# 404                   0
# 433                 NaN
# ...                 ...
# OLT                   0
# RNT                   0
# OPEN                  0
# SIGNA        2139048800
# UPR                   0
#
# [7771 rows x 6 columns]

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df["IsTrading"]==True].copy()
crypto_df
# Out:
#               CoinName  Algorithm IsTrading ProofType   TotalCoinsMined  \
# 42             42 Coin     Scrypt      True   PoW/PoS         41.999952
# 300          300 token        N/A      True       N/A               300
# 365            365Coin        X11      True   PoW/PoS                 0
# 404            404Coin     Scrypt      True   PoW/PoS                 0
# 611          SixEleven    SHA-256      True       PoW                 0
# ...                ...        ...       ...       ...               ...
# OLT          OneLedger        N/A      True       N/A        1000000000
# RNT    OneRoot Network        N/A      True       N/A         400000000
# OPEN     Open Platform        N/A      True       N/A        1745447045
# SIGNA            Signa  Shabal256      True       PoC        2139048800
# UPR             Upfire        N/A      True       N/A  772299898.370118
#
#       CirculatingSupply
# 42            41.999952
# 300                   0
# 365                   0
# 404                   0
# 611                   0
# ...                 ...
# OLT                   0
# RNT                   0
# OPEN                  0
# SIGNA        2139048800
# UPR                   0
#
# [6297 rows x 6 columns]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df.Algorithm != "N/A"].copy()
crypto_df
# Out:
#         CoinName  Algorithm IsTrading ProofType  TotalCoinsMined  \
# 42       42 Coin     Scrypt      True   PoW/PoS        41.999952
# 365      365Coin        X11      True   PoW/PoS                0
# 404      404Coin     Scrypt      True   PoW/PoS                0
# 611    SixEleven    SHA-256      True       PoW                0
# 808          808    SHA-256      True   PoW/PoS                0
# ...          ...        ...       ...       ...              ...
# NANO        Nano    Blake2b      True       PoW        133248290
# NAV      NavCoin        X13      True   PoW/PoS  72827352.565308
# NEBL      Neblio        PoS      True       N/A  18959467.798138
# NVC     NovaCoin     Scrypt      True   PoW/PoS   3582622.714205
# SIGNA      Signa  Shabal256      True       PoC       2139048800
#
#       CirculatingSupply
# 42            41.999952
# 365                   0
# 404                   0
# 611                   0
# 808                   0
# ...                 ...
# NANO                  0
# NAV                   0
# NEBL                  0
# NVC                   0
# SIGNA        2139048800
#
# [1646 rows x 6 columns]

# %%
# Remove the "IsTrading" column
crypto_df.drop(columns="IsTrading", inplace=True)
crypto_df.tail(10)
# Out:
#        CoinName  Algorithm ProofType  TotalCoinsMined CirculatingSupply
# KMD      Komodo   Equihash  dPoW/PoW  132226914.13131                 0
# LTC    Litecoin     Scrypt       PoW  69626008.233471   69626008.233471
# MEC    MegaCoin     Scrypt       PoW    39854933.7431                 0
# MONA   MonaCoin     Scrypt       PoW  84796674.971579                 0
# NMC    Namecoin    SHA-256       PoW         17983800                 0
# NANO       Nano    Blake2b       PoW        133248290                 0
# NAV     NavCoin        X13   PoW/PoS  72827352.565308                 0
# NEBL     Neblio        PoS       N/A  18959467.798138                 0
# NVC    NovaCoin     Scrypt   PoW/PoS   3582622.714205                 0
# SIGNA     Signa  Shabal256       PoC       2139048800        2139048800

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna(how='any',axis=0)

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df.TotalCoinsMined != 0]
crypto_df
# Out:
#              CoinName  Algorithm ProofType  TotalCoinsMined CirculatingSupply
# 42            42 Coin     Scrypt   PoW/PoS        41.999952         41.999952
# NSR          NuShares        PoS       PoS  6172691537.8311                 0
# TRI    Triangles Coin        X13   PoW/PoS    191620.842403                 0
# CMTC        CometCoin     Scrypt       PoW           872830                 0
# CHAT         OpenChat     Scrypt   PoW/PoS       1000000000                 0
# ...               ...        ...       ...              ...               ...
# NANO             Nano    Blake2b       PoW        133248290                 0
# NAV           NavCoin        X13   PoW/PoS  72827352.565308                 0
# NEBL           Neblio        PoS       N/A  18959467.798138                 0
# NVC          NovaCoin     Scrypt   PoW/PoS   3582622.714205                 0
# SIGNA           Signa  Shabal256       PoC       2139048800        2139048800
#
# [307 rows x 5 columns]

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[
    (crypto_df.CoinName != "N/A") & 
    (crypto_df.Algorithm != "N/A") & 
    (crypto_df.ProofType != "N/A") & 
    (crypto_df.TotalCoinsMined != "N/A") &
    (crypto_df.CirculatingSupply != "N/A")
].copy()
crypto_df
# Out:
#              CoinName  Algorithm ProofType  TotalCoinsMined CirculatingSupply
# 42            42 Coin     Scrypt   PoW/PoS        41.999952         41.999952
# NSR          NuShares        PoS       PoS  6172691537.8311                 0
# TRI    Triangles Coin        X13   PoW/PoS    191620.842403                 0
# CMTC        CometCoin     Scrypt       PoW           872830                 0
# CHAT         OpenChat     Scrypt   PoW/PoS       1000000000                 0
# ...               ...        ...       ...              ...               ...
# NMC          Namecoin    SHA-256       PoW         17983800                 0
# NANO             Nano    Blake2b       PoW        133248290                 0
# NAV           NavCoin        X13   PoW/PoS  72827352.565308                 0
# NVC          NovaCoin     Scrypt   PoW/PoS   3582622.714205                 0
# SIGNA           Signa  Shabal256       PoC       2139048800        2139048800
#
# [133 rows x 5 columns]

# %%
crypto_df_with_name = crypto_df.copy()

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coinName_df = crypto_df.index
coinName_df
# Out:
# Index(['42', 'NSR', 'TRI', 'CMTC', 'CHAT', 'QRL', 'PURA', 'BTCP', 'ADK',
#        'DAPS',
#        ...
#        'KCASH', 'KMD', 'LTC', 'MEC', 'MONA', 'NMC', 'NANO', 'NAV', 'NVC',
#        'SIGNA'],
#       dtype='object', length=133)

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df.drop(columns="CoinName",inplace=True)
crypto_df
# Out:
#        Algorithm ProofType  TotalCoinsMined CirculatingSupply
# 42        Scrypt   PoW/PoS        41.999952         41.999952
# NSR          PoS       PoS  6172691537.8311                 0
# TRI          X13   PoW/PoS    191620.842403                 0
# CMTC      Scrypt       PoW           872830                 0
# CHAT      Scrypt   PoW/PoS       1000000000                 0
# ...          ...       ...              ...               ...
# NMC      SHA-256       PoW         17983800                 0
# NANO     Blake2b       PoW        133248290                 0
# NAV          X13   PoW/PoS  72827352.565308                 0
# NVC       Scrypt   PoW/PoS   3582622.714205                 0
# SIGNA  Shabal256       PoC       2139048800        2139048800
#
# [133 rows x 4 columns]

# %%
# Create dummy variables for text features
encoded_features_df = pd.get_dummies(crypto_df, columns=["Algorithm", "ProofType"])
encoded_features_df
# Out:
#        TotalCoinsMined CirculatingSupply  Algorithm_Autolykos  \
# 42           41.999952         41.999952                    0
# NSR    6172691537.8311                 0                    0
# TRI      191620.842403                 0                    0
# CMTC            872830                 0                    0
# CHAT        1000000000                 0                    0
# ...                ...               ...                  ...
# NMC           17983800                 0                    0
# NANO         133248290                 0                    0
# NAV    72827352.565308                 0                    0
# NVC     3582622.714205                 0                    0
# SIGNA       2139048800        2139048800                    0
#
#        Algorithm_BEP-2  Algorithm_BEP-20 Token  Algorithm_BLAKE256  \
# 42                   0                       0                   0
# NSR                  0                       0                   0
# TRI                  0                       0                   0
# CMTC                 0                       0                   0
# CHAT                 0                       0                   0
# ...                ...                     ...                 ...
# NMC                  0                       0                   0
# NANO                 0                       0                   0
# NAV                  0                       0                   0
# NVC                  0                       0                   0
# SIGNA                0                       0                   0
#
#        Algorithm_BMW512 / Echo512  Algorithm_Blake2B + SHA3  \
# 42                              0                         0
# NSR                             0                         0
# TRI                             0                         0
# CMTC                            0                         0
# CHAT                            0                         0
# ...                           ...                       ...
# NMC                             0                         0
# NANO                            0                         0
# NAV                             0                         0
# NVC                             0                         0
# SIGNA                           0                         0
#
#        Algorithm_Blake2b  Algorithm_C31  ...  ProofType_PoW/PoSe  \
# 42                     0              0  ...                   0
# NSR                    0              0  ...                   0
# TRI                    0              0  ...                   0
# CMTC                   0              0  ...                   0
# CHAT                   0              0  ...                   0
# ...                  ...            ...  ...                 ...
# NMC                    0              0  ...                   0
# NANO                   1              0  ...                   0
# NAV                    0              0  ...                   0
# NVC                    0              0  ...                   0
# SIGNA                  0              0  ...                   0
#
#        ProofType_PoW/nPoS  ProofType_ProgPoW/PoS  \
# 42                      0                      0
# NSR                     0                      0
# TRI                     0                      0
# CMTC                    0                      0
# CHAT                    0                      0
# ...                   ...                    ...
# NMC                     0                      0
# NANO                    0                      0
# NAV                     0                      0
# NVC                     0                      0
# SIGNA                   0                      0
#
#        ProofType_Proof of Authority  ProofType_Proof-of-Work  ProofType_SPoS  \
# 42                                0                        0               0
# NSR                               0                        0               0
# TRI                               0                        0               0
# CMTC                              0                        0               0
# CHAT                              0                        0               0
# ...                             ...                      ...             ...
# NMC                               0                        0               0
# NANO                              0                        0               0
# NAV                               0                        0               0
# NVC                               0                        0               0
# SIGNA                             0                        0               0
#
#        ProofType_TPoS  ProofType_Zero-Knowledge Proof  ProofType_dPoW  \
# 42                  0                               0               0
# NSR                 0                               0               0
# TRI                 0                               0               0
# CMTC                0                               0               0
# CHAT                0                               0               0
# ...               ...                             ...             ...
# NMC                 0                               0               0
# NANO                0                               0               0
# NAV                 0                               0               0
# NVC                 0                               0               0
# SIGNA               0                               0               0
#
#        ProofType_dPoW/PoW
# 42                      0
# NSR                     0
# TRI                     0
# CMTC                    0
# CHAT                    0
# ...                   ...
# NMC                     0
# NANO                    0
# NAV                     0
# NVC                     0
# SIGNA                   0
#
# [133 rows x 82 columns]

# %%
# Standardize data
encoded_features_scaled = StandardScaler().fit_transform(encoded_features_df)
encoded_features_scaled
# Out:
# array([[-0.16752606, -0.10797706, -0.08703883, ..., -0.08703883,
#         -0.08703883, -0.08703883],
#        [-0.11711374, -0.10797707, -0.08703883, ..., -0.08703883,
#         -0.08703883, -0.08703883],
#        [-0.1675245 , -0.10797707, -0.08703883, ..., -0.08703883,
#         -0.08703883, -0.08703883],
#        ...,
#        [-0.16693128, -0.10797707, -0.08703883, ..., -0.08703883,
#         -0.08703883, -0.08703883],
#        [-0.16749681, -0.10797707, -0.08703883, ..., -0.08703883,
#         -0.08703883, -0.08703883],
#        [-0.15005647,  0.07281094, -0.08703883, ..., -0.08703883,
#         -0.08703883, -0.08703883]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
crypto_pca = pca.fit_transform(encoded_features_scaled)

pcs_df = pd.DataFrame(
    data=crypto_pca, index=coinName_df,columns=["PC 1", "PC 2", "PC 3"]
)
pcs_df
# Out:
#            PC 1      PC 2      PC 3
# 42     0.698362 -1.288289 -1.103989
# NSR    1.352145 -0.461180 -0.689938
# TRI    1.462562 -1.678126 -1.390150
# CMTC  -1.047678 -0.149514 -0.267213
# CHAT   0.698820 -1.285196 -1.103923
# ...         ...       ...       ...
# NMC   -1.603583  0.588150  0.192789
# NANO  -1.669371  0.450630  0.255502
# NAV    1.462596 -1.677902 -1.390145
# NVC    0.698363 -1.288278 -1.103988
# SIGNA  0.981005 -1.033499 -0.651986
#
# [133 rows x 3 columns]

# %%
# Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.02842379, 0.02644755, 0.02477487])

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using altair
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
alt.Chart(df_elbow).mark_line().encode(x="k", y="inertia").properties(
    title='Elbow Curve'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with k=4

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Append class to pcs_df
pcs_df["class"] = model.labels_

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features
crypto_df_with_class = crypto_df_with_name.join(pcs_df,how="inner")
crypto_df_with_class.head()
# Out:
#             CoinName Algorithm ProofType  TotalCoinsMined CirculatingSupply  \
# 42           42 Coin    Scrypt   PoW/PoS        41.999952         41.999952
# NSR         NuShares       PoS       PoS  6172691537.8311                 0
# TRI   Triangles Coin       X13   PoW/PoS    191620.842403                 0
# CMTC       CometCoin    Scrypt       PoW           872830                 0
# CHAT        OpenChat    Scrypt   PoW/PoS       1000000000                 0
#
#           PC 1      PC 2      PC 3  class
# 42    0.698362 -1.288289 -1.103989      0
# NSR   1.352145 -0.461180 -0.689938      0
# TRI   1.462562 -1.678126 -1.390150      0
# CMTC -1.047678 -0.149514 -0.267213      1
# CHAT  0.698820 -1.285196 -1.103923      0

# %%
# Display coin class based on PC 1 & PC 2
alt.Chart(crypto_df_with_class).mark_circle(size=60).encode(
    x="PC 1",
    y="PC 2",
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "CirculatingSupply"],
    color="class",
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
x_y_scaled = StandardScaler().fit_transform(crypto_df_with_class[["TotalCoinsMined","CirculatingSupply"]])

crypto_df_with_class[["TotalCoinsMinedScaled","CirculatingSupplyScaled"]] = x_y_scaled
crypto_df_with_class
# Out:
#              CoinName  Algorithm ProofType  TotalCoinsMined CirculatingSupply  \
# 42            42 Coin     Scrypt   PoW/PoS        41.999952         41.999952
# NSR          NuShares        PoS       PoS  6172691537.8311                 0
# TRI    Triangles Coin        X13   PoW/PoS    191620.842403                 0
# CMTC        CometCoin     Scrypt       PoW           872830                 0
# CHAT         OpenChat     Scrypt   PoW/PoS       1000000000                 0
# ...               ...        ...       ...              ...               ...
# NMC          Namecoin    SHA-256       PoW         17983800                 0
# NANO             Nano    Blake2b       PoW        133248290                 0
# NAV           NavCoin        X13   PoW/PoS  72827352.565308                 0
# NVC          NovaCoin     Scrypt   PoW/PoS   3582622.714205                 0
# SIGNA           Signa  Shabal256       PoC       2139048800        2139048800
#
#            PC 1      PC 2      PC 3  class  TotalCoinsMinedScaled  \
# 42     0.698362 -1.288289 -1.103989      0              -0.167526
# NSR    1.352145 -0.461180 -0.689938      0              -0.117114
# TRI    1.462562 -1.678126 -1.390150      0              -0.167525
# CMTC  -1.047678 -0.149514 -0.267213      1              -0.167519
# CHAT   0.698820 -1.285196 -1.103923      0              -0.159359
# ...         ...       ...       ...    ...                    ...
# NMC   -1.603583  0.588150  0.192789      1              -0.167379
# NANO  -1.669371  0.450630  0.255502      1              -0.166438
# NAV    1.462596 -1.677902 -1.390145      0              -0.166931
# NVC    0.698363 -1.288278 -1.103988      0              -0.167497
# SIGNA  0.981005 -1.033499 -0.651986      0              -0.150056
#
#        CirculatingSupplyScaled
# 42                   -0.107977
# NSR                  -0.107977
# TRI                  -0.107977
# CMTC                 -0.107977
# CHAT                 -0.107977
# ...                        ...
# NMC                  -0.107977
# NANO                 -0.107977
# NAV                  -0.107977
# NVC                  -0.107977
# SIGNA                 0.072811
#
# [133 rows x 11 columns]

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
alt.Chart(crypto_df_with_class).mark_circle(size=60).encode(
    x="TotalCoinsMinedScaled",
    y="CirculatingSupplyScaled",
    tooltip=["CoinName"],
    color="CoinName",
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
display(crypto_df_with_class[["CoinName", "Algorithm", "ProofType", "TotalCoinsMined", "CirculatingSupply", "class"]])
# Out:
#              CoinName  Algorithm ProofType  TotalCoinsMined CirculatingSupply  \
# 42            42 Coin     Scrypt   PoW/PoS        41.999952         41.999952
# NSR          NuShares        PoS       PoS  6172691537.8311                 0
# TRI    Triangles Coin        X13   PoW/PoS    191620.842403                 0
# CMTC        CometCoin     Scrypt       PoW           872830                 0
# CHAT         OpenChat     Scrypt   PoW/PoS       1000000000                 0
# ...               ...        ...       ...              ...               ...
# NMC          Namecoin    SHA-256       PoW         17983800                 0
# NANO             Nano    Blake2b       PoW        133248290                 0
# NAV           NavCoin        X13   PoW/PoS  72827352.565308                 0
# NVC          NovaCoin     Scrypt   PoW/PoS   3582622.714205                 0
# SIGNA           Signa  Shabal256       PoC       2139048800        2139048800
#
#        class
# 42         0
# NSR        0
# TRI        0
# CMTC       1
# CHAT       0
# ...      ...
# NMC        1
# NANO       1
# NAV        0
# NVC        0
# SIGNA      0
#
# [133 rows x 6 columns]

# %%
# Print the total number of tradable cryptocurrencies
total_rows = crypto_df_with_class.count()
total_rows["CoinName"]
# Out:
# 133
